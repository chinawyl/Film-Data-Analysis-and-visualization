# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False

# %%
data = pd.read_csv('../3-Data_Cleaning/movies_half.csv')

# %%
data
# Out:
#                                                     电影名                    导演  \
# 0                                         角斗士 Gladiator               雷德利·斯科特
# 1              外出就餐3：饕餮自助 Eating Out 3: All You Can Eat                 葛伦·盖洛
# 2                          蝴蝶效应2 The Butterfly Effect 2             约翰·R·莱昂耐迪
# 3                                   铁血柔情 Love Me Tender              罗伯特·D·韦布
# 4                                          冰川时代 Ice Age              卡洛斯·沙尔丹哈
# 5                                                  危情雪夜                   陈国星
# 6                     李尔王 Great Performances: King Lear                特雷弗·纳恩
# 7                         极限特工2 xXx: State of the Union                李·塔玛霍瑞
# 8                                         大逃杀 バトル・ロワイアル                  深作欣二
# 9                                                  蜀山奇侠                    萧笙
# 10                                      范海辛 Van Helsing               斯蒂芬·索莫斯
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6141 entries, 0 to 6140
# Data columns (total 8 columns):
# 电影名         6141 non-null object
# 导演          6141 non-null object
# 编剧          6141 non-null object
# 演员          6141 non-null object
# 类型          6141 non-null object
# 电影时长(分钟)    6141 non-null int64
# 上映时间(年)     6141 non-null int64
# 评分          6141 non-null float64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 383.9+ KB

# %%
# 1.数据分类 

#添加列电影数目
data['电影数目'] = 1

#按电影类型分类并计算平均时长
grouped = data.groupby(by='类型')
datas = grouped.sum()
datas['平均时长'] = (datas['电影时长(分钟)']/datas['电影数目'])

#选择绘图列
MovieType = list(datas.index)
AverageTime = list(datas['平均时长'])

# %%
# 2.绘制图片

#设置图片大小
plt.figure(figsize=(20,8),dpi=80)

#设置字体
my_font = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=16)
my_fonts = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=20)

#绘制图片
plt.barh(range(len(MovieType)),AverageTime,height=0.3,color="green")

#设置y轴的刻度
plt.yticks(range(len(MovieType)),MovieType,fontproperties=my_font)

#添加描述信息
plt.xlabel("平均时长",fontproperties=my_font,color='blue')
plt.ylabel("电影类型",fontproperties=my_font,color='purple')
plt.title("不同类型电影的平均时长",fontproperties=my_fonts,color='red')


#绘制表格
plt.grid()

#保存图片
plt.savefig("./不同类型电影的平均时长.png") #保存为.svg格式矢量图，不会有失帧

#展示图片
plt.show()
