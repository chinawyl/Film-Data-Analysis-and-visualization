# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
data = pd.read_csv('../3-Data_Cleaning/movies_all.csv')

# %%
data
# Out:
#                                                     电影名                    导演  \
# 0                                         角斗士 Gladiator               雷德利·斯科特
# 1              外出就餐3：饕餮自助 Eating Out 3: All You Can Eat                 葛伦·盖洛
# 2                          蝴蝶效应2 The Butterfly Effect 2             约翰·R·莱昂耐迪
# 3                                   铁血柔情 Love Me Tender              罗伯特·D·韦布
# 4                                          冰川时代 Ice Age              卡洛斯·沙尔丹哈
# 5                                                  危情雪夜                   陈国星
# 6                     李尔王 Great Performances: King Lear                特雷弗·纳恩
# 7                         极限特工2 xXx: State of the Union                李·塔玛霍瑞
# 8                                         大逃杀 バトル・ロワイアル                  深作欣二
# 9                                                  蜀山奇侠                    萧笙
# 10                                      范海辛 Van Helsing               斯蒂芬·索莫斯
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6141 entries, 0 to 6140
# Data columns (total 11 columns):
# 电影名         6141 non-null object
# 导演          6141 non-null object
# 编剧          6141 non-null object
# 演员          6141 non-null object
# 类型          6141 non-null object
# 电影时长(分钟)    6141 non-null int64
# 上映时间(年)     6141 non-null int64
# 评分          6141 non-null float64
# 票房          6141 non-null float64
# 发行公司        6141 non-null object
# 制片公司        6141 non-null object
# dtypes: float64(2), int64(2), object(7)
# memory usage: 527.8+ KB

# %%
# 1.数据选择与分类

#选取票房不为0的数据
data = data[data['票房']!=0]

#按照导演分类
grouped = data.groupby(by='导演')

#将导演与相对应的总票房存入列表当中
Director = []
BoxOffice = []
for i,j in grouped:
    Director.append(i)
    BoxOffice.append(j['票房'].sum().round(1))

# %%
# 2.数据的拼接排序与选择

#拼接列表为Dataframe并按票房大小逆序排序
Director_BoxOffice = pd.DataFrame({'导演':Director,'票房':BoxOffice})
Director_BoxOffice.sort_values(by='票房',ascending=False,inplace=True)

#取出总票房前10的导演与票房数据
Director_ten = list(Director_BoxOffice.head(10).loc[:,'导演'].values)
BoxOffice_ten = list(Director_BoxOffice.head(10).loc[:,'票房'].values)

#查看数据
Director_BoxOffice
# Out:
#       导演        票房
# 44    吴京  622484.1
# 56   周星驰  532656.2
# 256   郭帆  514017.7
# 299   饺子  501334.6
# 163  林超贤  499282.5
# 20   冯小刚  483242.6
# 234  许诚毅  467709.9
# 114   徐克  467683.1
# 284  陈思诚  462766.2
# 272  陈凯歌  403440.0
# 267   闫非  398918.6
# 72    宁浩  392325.4
# 294   韩寒  340593.6
# 125  文牧野  309996.1
# 132  李仁港  298806.8
# 252  郑保瑞  298089.8
# 115   徐峥  288605.1
# 196  田羽生  260962.6
# 106  张艺谋  259726.9
# 80    宋阳  220174.9
# 258  郭敬明  217399.5
# 280  陈国辉  209796.2
# 60   唐季礼  184962.3
# 66    姜文  176931.2
# 129  曾国祥  172528.5
# 7    乌尔善  170507.4
# 62    大鹏  161947.0
# 1     丁晟  158744.8
# 30   刘若英  136152.5
# 225  薛晓路  135721.9
# ..   ...       ...
# 219   范俭     185.2
# 237   谭华     180.5
# 204   竹卿     171.3
# 23    冯超     163.3
# 281  陈士争     110.6
# 135  李前宽      89.6
# 307  黄修平      57.0
# 81   宫晓东      48.0
# 266   闫然      47.3
# 300   马凯      41.6
# 2    丁荫楠      40.3
# 55    周旭      35.5
# 313  龚应恬      32.3
# 287   陈苗      32.3
# 52    吴琦      29.6
# ...

# %%
# 3.绘制图片

#设置图片大小
plt.figure(figsize=(12,9),dpi=80)

#设置字体
my_font = FontProperties(fname=r"C:\Windows\Fonts\simsun.ttc", size=12)
my_fonts = FontProperties(fname=r"C:\Windows\Fonts\方正粗黑宋简体.ttf", size=14)

#绘制图片
plt.bar(Director_ten,BoxOffice_ten,width=0.8)

#设置x轴的刻度
plt.xticks(Director_ten,Director_ten,fontproperties=my_font)

#绘制表格
plt.grid(alpha=1) #alpha是表格透明度

#添加描述信息
plt.xlabel("导演",fontproperties=my_fonts,color='blue')
plt.ylabel("总票房(万)",fontproperties=my_fonts,color='green')
plt.title("总票房最高的10名导演",fontproperties=my_fonts,color='red')

#保存图片
plt.savefig("./总票房最高的10名导演.png") #保存为.svg格式矢量图，不会有失帧

#展示图片
plt.show()
